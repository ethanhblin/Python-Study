# %% [markdown]
# # 01 - Print

# %%
print("hello world") # This is a comment

print('she said "hello" and then left.')

print("she said" + " hello and then left.")

print("Ethan" + " Lin" )
# Out:
# hello world
# she said "hello" and then left.
# she said hello and then left.
# Ethan Lin

# %% [markdown]
# # 02 - Input ``Input``

# %%
#input("what is your name? ")

print("Hello" + input("What is your name? ") + "!")

print("hello", input("whats your age: "))
# Out:
# Hellod!
# hello d

# %% [markdown]
# # 03 - Variable
# **Rules**:
# - Can contain letters, number, and underscores
# - Must start with letter or underscore
# - Case-sensitive
# - Cannot be Python keywords
#
# **Best Practice**
# - Use descriptive names (age instead a)
# - Use snake_case(total_price)
# - Avoid single-letter names (except in loops)
# - Follow PEP 8 guildlines

# %%
# System reads code right to left.
# Code below is incorrect

# input("what is your name?") = name 
# print(name)
# Out:
#   Cell In[2], line 4
#     input("what is your name?") = name
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %%
name = input("what is your name?")
print(name)


name = "alex"
print (name)

my_name = "Ethan"

print(my_name)
# Out:
# Ethan
# alex
# Ethan

# %% [markdown]
# # 04 - Data Types
#
# 1. integer = ``int`` (eg. int = 3)
#
# 2. decimal = ``float`` (eg. float = 34.5)
#
# 3. text = ``string`` (string = "Ethan")
#
# 4. boolean = ``bool`` (True or False / Yes or No)

# %%
user_name = "Alice"
total_price = 100.50
is_valid = True
count = 10

# %% [markdown]
# # 05 - Type

# %%
print(type(user_name))

print(type(total_price))

print(type(is_valid))

print(type(count))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'bool'>
# <class 'int'>

# %% [markdown]
# # 06 - input and data type
# the input function will always give you a string
#
# Example Below
#
# you enter a number 14, and 14 will be turn into a string instead of a integer and stored into age

# %%
age = input("what is your age?")
print(type(age))
print(age)
# Out:
# <class 'str'>
# 15

# %% [markdown]
# # 07 - f-string
#
# f-string is used if there is a varible the curly bracket.
# you would set a varible and then when you print it, you would you have to put an f before the double quote. Curly bracket is invisible

# %%
age = 13

print(f"I am {age} years old")
# Out:
# I am 13 years old

# %% [markdown]
#  Project 1 Band Name Generator
#
# importing your fav type of animal and the city you like the most
# generate a band name according to those input.
#
# example city:victoria , fav animal:dog
# it would generate victoria dog band.

# %%
print("Welcome to Ethans band name generator!")
  
animal = input("whats your favourtie animal?")

city = input("whats your favourite city? ")

print(f'Your generated band name is "{city} {animal} band".')
# Out:
# Welcome to Ethans band name generator!
# Your generated band name is "  band".

# %% [markdown]
# Assignment
# Please review all the notes above
# TEST NEXT WEEK

# %%
myvarr = input("how is your day")

print(type(myvarr))
# Out:
# <class 'str'>
